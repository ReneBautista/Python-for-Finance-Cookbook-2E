# %% [markdown]
# Please run those two cells before running the Notebook!
#
# As those plotting settings are standard throughout the book, we do not show them in the book every time we plot something.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
from pandas.errors import SettingWithCopyWarning
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.simplefilter(action="ignore", category=SettingWithCopyWarning)

# feel free to modify, for example, change the context to "notebook"
sns.set_theme(context="talk", style="whitegrid", 
              palette="colorblind", color_codes=True, 
              rc={"figure.figsize": [12, 8]})

# %% [markdown]
# # Chapter 1 - Acquiring Financial Data

# %% [markdown]
# ## 1.1 Getting data from Yahoo Finance

# %% [markdown]
# ### How to do it...

# %% [markdown]
# 1. Import the libraries:

# %%
import pandas as pd 
import yfinance as yf

# %% [markdown]
# 2. Download the data:

# %%
df = yf.download("SOL-USD", 
                 start="2021-01-01", 
                 end="2021-06-30",
                 progress=False)

# %% [markdown]
# 3. Inspect the data:

# %%
print(f"Downloaded {len(df)} rows of data.")
df
# Out:
# Downloaded 180 rows of data.
# Price                      Adj Close      Close       High        Low  \
# Ticker                       SOL-USD    SOL-USD    SOL-USD    SOL-USD
# Date
# 2021-01-01 00:00:00+00:00   1.842084   1.842084   1.859656   1.502038
# 2021-01-02 00:00:00+00:00   1.799275   1.799275   1.989295   1.721482
# 2021-01-03 00:00:00+00:00   2.161752   2.161752   2.364981   1.799902
# 2021-01-04 00:00:00+00:00   2.485097   2.485097   2.485097   1.876342
# 2021-01-05 00:00:00+00:00   2.157217   2.157217   2.502616   2.077742
# ...                              ...        ...        ...        ...
# 2021-06-25 00:00:00+00:00  28.698862  28.698862  32.902515  28.035080
# 2021-06-26 00:00:00+00:00  29.712854  29.712854  30.007036  26.710814
# 2021-06-27 00:00:00+00:00  31.929392  31.929392  31.929392  29.271196
# 2021-06-28 00:00:00+00:00  32.927780  32.927780  34.243225  31.035128
# 2021-06-29 00:00:00+00:00  33.866802  33.866802  35.788578  32.726685
#
# Price                           Open     Volume
# Ticker                       SOL-USD    SOL-USD
# Date
# 2021-01-01 00:00:00+00:00   1.509775   25722549
# 2021-01-02 00:00:00+00:00   1.845586   31671064
# 2021-01-03 00:00:00+00:00   1.799902   55073422
# 2021-01-04 00:00:00+00:00   2.162412   59955405
# 2021-01-05 00:00:00+00:00   2.490982   50555207
# ...                              ...        ...
# 2021-06-25 00:00:00+00:00  31.168531  632052177
# 2021-06-26 00:00:00+00:00  28.607899  560342710
# 2021-06-27 00:00:00+00:00  29.752640  497353288
# 2021-06-28 00:00:00+00:00  31.880831  473612135
# 2021-06-29 00:00:00+00:00  33.009785  471854279
#
# [180 rows x 6 columns]

# %% [markdown]
# ### There's more

# %% [markdown]
# We can also use the `Ticker` class to download the historical prices and much more.

# %%
# instantiate the Ticker class
aapl_data = yf.Ticker("AAPL")

# %%
# get the last month of historical prices
aapl_data.history()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024

#  'compensationAsOfEpochDate': 1703980800,
#  'irWebsite': 'http://investor.apple.com/',
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 222.72,
#  'open': 224.625,
#  'dayLow': 224.57,
#  'dayHigh': 227.87,
#  'regularMarketPreviousClose': 222.72,
#  'regularMarketOpen': 224.625,
#  'regularMarketDayLow': 224.57,
#  'regularMarketDayHigh': 227.87,
#  'dividendRate': 1.0,
#  'dividendYield': 0.0044,
#  'exDividendDate': 1731024000,
#  'payoutRatio': 0.1612,
#  'fiveYearAvgDividendYield': 0.63,
#  'beta': 1.24,
#  'trailingPE': 37.47611,
#  'forwardPE': 27.374247,
#  'volume': 41056585,
#  'regularMarketVolume': 41056585,
#  'averageVolume': 47785407,
#  'averageVolume10days': 44575070,
#  'averageDailyVolume10Day': 44575070,
#  'bid': 225.9,
#  'ask': 235.89,
#  'bidSize': 100,
#  'askSize': 100,
#  'marketCap': 3438542061568,
#  'fiftyTwoWeekLow': 164.08,
#  'fiftyTwoWeekHigh': 237.49,
#  'priceToSalesTrailing12Months': 8.793438,
#  'fiftyDayAverage': 226.8564,
#  'twoHundredDayAverage': 202.5902,
#  'trailingAnnualDividendRate': 0.98,
#  'trailingAnnualDividendYield': 0.004400144,
#  'currency': 'USD',
#  'enterpriseValue': 3492435460096,
#  'profitMargins': 0.23971,
#  'floatShares': 15091184209,
#  'sharesOutstanding': 15115799552,
#  'sharesShort': 140919653,
#  'sharesShortPriorMonth': 130539888,
#  'sharesShortPreviousMonthDate': 1726185600,
#  'dateShortInterest': 1728950400,
#  'sharesPercentSharesOut': 0.0093,
#  'heldPercentInsiders': 0.027190002,
#  'heldPercentInstitutions': 0.61341,
#  'shortRatio': 2.47,
#  'shortPercentOfFloat': 0.0093,
#  'impliedSharesOutstanding': 15169599488,
#  'bookValue': 3.767,
#  'priceToBook': 60.387577,
#  'lastFiscalYearEnd': 1727481600,
#  'nextFiscalYearEnd': 1759017600,
#  'mostRecentQuarter': 1727481600,
#  'earningsQuarterlyGrowth': -0.358,
#  'netIncomeToCommon': 93736001536,
#  'trailingEps': 6.07,
#  'forwardEps': 8.31,
#  'pegRatio': 2.17,
#  'lastSplitFactor': '4:1',
#  'lastSplitDate': 1598832000,
#  'enterpriseToRevenue': 8.931,
#  'enterpriseToEbitda': 25.935,
#  '52WeekChange': 0.19484973,
#  'SandP52WeekChange': 0.34285796,
#  'lastDividendValue': 0.25,
#  'lastDividendDate': 1723420800,
#  'exchange': 'NMS',
#  'quoteType': 'EQUITY',
#  'symbol': 'AAPL',
#  'underlyingSymbol': 'AAPL',
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'firstTradeDateEpochUtc': 345479400,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EST',
#  'uuid': '8b10e4ae-9eeb-3684-921a-9ab27e4d87aa',
#  'messageBoardId': 'finmb_24937',
#  'gmtOffSetMilliseconds': -18000000,
#  'currentPrice': 227.48,
#  'targetHighPrice': 300.0,
#  'targetLowPrice': 183.86,
#  'targetMeanPrice': 240.07,
#  'targetMedianPrice': 242.89,
#  'recommendationMean': 2.1,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 42,
#  'totalCash': 65171001344,
#  'totalCashPerShare': 4.311,
#  'ebitda': 134660997120,
#  'totalDebt': 119058997248,
#  'quickRatio': 0.745,
#  'currentRatio': 0.867,
#  'totalRevenue': 391034994688,
#  'debtToEquity': 209.059,
#  'revenuePerShare': 25.485,
#  'returnOnAssets': 0.21464,
#  'returnOnEquity': 1.5741299,
#  'freeCashflow': 110846001152,
#  'operatingCashflow': 118254002176,
#  'earningsGrowth': -0.341,
#  'revenueGrowth': 0.061,
#  'grossMargins': 0.46206,
#  'ebitdaMargins': 0.34437,
#  'operatingMargins': 0.31171,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 2.3551}

# %%
# show corporate actions
aapl_data.actions
# Out:
# Empty DataFrame
# Columns: [Dividends, Stock Splits]
# Index: []

# %%
# show financials
aapl_data.financials
# Out:
#                                                         2024-09-30  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                
# Reconciled Cost Of Revenue                                    NaN
# EBITDA                                                        NaN
# EBIT                                                          NaN
# Net Interest Income                                   890000000.0
# Interest Expense                                     2873000000.0
# Interest Income                                      3763000000.0
# Normalized Income                                             NaN
# Net Income From Continuing And Discontinued Ope...            NaN
# Total Expenses                                                NaN
# Total Operating Income As Reported                            NaN
# Diluted Average Shares                              17528214000.0
# Basic Average Shares                                17352119000.0
# Diluted EPS                                                  3.28
# Basic EPS                                                    3.31
# Diluted NI Availto Com Stockholders                           NaN
# Net Income Common Stockholders                                NaN
# Net Income                                                    NaN
# Net Income Including Noncontrolling Interests                 NaN
# Net Income Continuous Operations                              NaN
# Tax Provision                                                 NaN
# Pretax Income                                                 NaN
# Other Income Expense                                          NaN
# Other Non Operating Income Expenses                           NaN
# Net Non Operating Interest Income Expense             890000000.0
# Interest Expense Non Operating                       2873000000.0
# Interest Income Non Operating                        3763000000.0
# Operating Income                                              NaN
# Operating Expense                                             NaN
# Research And Development                                      NaN
# Selling General And Administration                            NaN
# Gross Profit                                                  NaN
# Cost Of Revenue                                               NaN
# Total Revenue                                                 NaN
# Operating Revenue                                             NaN

# %%
# show quarterly financials
aapl_data.quarterly_financials
# Out:
#                                                        2024-09-30  \
# Tax Effect Of Unusual Items                                   0.0
# Tax Rate For Calcs                                           0.21
# Normalized EBITDA                                   32502000000.0
# Net Income From Continuing Operation Net Minori...  14736000000.0
# Reconciled Depreciation                              2911000000.0
# Reconciled Cost Of Revenue                          51051000000.0
# EBITDA                                              32502000000.0
# EBIT                                                29591000000.0
# Net Interest Income                                           NaN
# Interest Expense                                              NaN
# Interest Income                                               NaN
# Normalized Income                                   14736000000.0
# Net Income From Continuing And Discontinued Ope...  14736000000.0
# Total Expenses                                      65339000000.0
# Total Operating Income As Reported                  29591000000.0
# Diluted Average Shares                              15242853000.0
# Basic Average Shares                                15171990000.0
# Diluted EPS                                                  0.97
# Basic EPS                                                    0.97
# Diluted NI Availto Com Stockholders                 14736000000.0
# Net Income Common Stockholders                      14736000000.0
# Net Income                                          14736000000.0
# Net Income Including Noncontrolling Interests       14736000000.0
# Net Income Continuous Operations                    14736000000.0
# Tax Provision                                       14874000000.0
# Pretax Income                                       29610000000.0
# Other Income Expense                                   19000000.0
# Other Non Operating Income Expenses                    19000000.0
# Net Non Operating Interest Income Expense                     NaN
# Interest Expense Non Operating                                NaN
# Interest Income Non Operating                                 NaN
# Operating Income                                    29591000000.0
# Operating Expense                                   14288000000.0
# Research And Development                             7765000000.0
# Selling General And Administration                   6523000000.0
# Gross Profit                                        43879000000.0
# Cost Of Revenue                                     51051000000.0
# Total Revenue                                       94930000000.0
# Operating Revenue                                   94930000000.0
#
#                                                        2024-06-30  \
# Tax Effect Of Unusual Items                                   0.0
# Tax Rate For Calcs                                          0.159
# Normalized EBITDA                                   28202000000.0
# Net Income From Continuing Operation Net Minori...  21448000000.0
# Reconciled Depreciation                              2850000000.0
# Reconciled Cost Of Revenue                          46099000000.0
# EBITDA                                              28202000000.0
# EBIT                                                25352000000.0
# Net Interest Income                                           NaN
# Interest Expense                                              NaN
# Interest Income                
# Total Expenses                                              NaN          NaN
# Total Operating Income As Reported                          NaN          NaN
# Diluted Average Shares                                      NaN          NaN
# Basic Average Shares                                        NaN          NaN
# Diluted EPS                                                 NaN          NaN
# Basic EPS                                                   NaN          NaN
# Diluted NI Availto Com Stockholders                         NaN          NaN
# Net Income Common Stockholders                              NaN          NaN
# Net Income                                                  NaN          NaN
# Net Income Including Noncontrolling Interests               NaN          NaN
# Net Income Continuous Operations                            NaN          NaN
# Tax Provision                                               NaN          NaN
# Pretax Income                                               NaN          NaN
# Other Income Expense                                        NaN          NaN
# Other Non Operating Income Expenses                         NaN          NaN
# Net Non Operating Interest Income Expense           -18000000.0  -12000000.0
# Interest Expense Non Operating                      998000000.0  930000000.0
# Interest Income Non Operating                       980000000.0  918000000.0
# Operating Income                                            NaN          NaN
# Operating Expense                                           NaN          NaN
# Research And Development                                    NaN          NaN
# Selling General And Administration                          NaN          NaN
# Gross Profit                                                NaN          NaN
# Cost Of Revenue                                             NaN          NaN
# Total Revenue                                               NaN          NaN
# Operating Revenue                                           NaN          NaN

# %%
# show earnings
aapl_data.earnings
# Out:
# /opt/anaconda3/envs/finance_book/lib/python3.13/site-packages/yfinance/scrapers/fundamentals.py:33: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)

# %%
# show quarterly earnings
aapl_data.quarterly_earnings

# %%
# show upcoming events, such as earnings
aapl_data.calendar

# %% [markdown]
# ## 1.2 Getting data from Nasdaq Data Link

# %% [markdown]
# ### How to do it...

# %% [markdown]
# 1. Import the libraries:

# %%
import pandas as pd 
import nasdaqdatalink

# %% [markdown]
# 2. Authenticate using the personal API key:

# %%
nasdaqdatalink.ApiConfig.api_key = "YOUR_KEY_HERE"

# %% [markdown]
# 3. Download the data:

# %%
df = nasdaqdatalink.get(dataset="WIKI/AAPL",
                        start_date="2011-01-01", 
                        end_date="2021-12-31")

# %% [markdown]
# 4. Inspect the data:

# %%
print(f"Downloaded {len(df)} rows of data.")
df.head()

# %% [markdown]
# ### There's more

# %% [markdown]
# 1. Download the data for multiple tickers using the `get_table` function:

# %%
COLUMNS = ["ticker", "date", "adj_close"]
df = nasdaqdatalink.get_table("WIKI/PRICES", 
                              ticker=["AAPL", "MSFT", "INTC"], 
                              qopts={"columns": COLUMNS}, 
                              date={"gte": "2011-01-01", 
                                    "lte": "2021-12-31"}, 
                              paginate=True)
df.head()

# %% [markdown]
# 2. Pivot the data from long to wide:

# %%
# set the date as index
df = df.set_index("date")

# use the pivot function to reshape the data
df_wide = df.pivot(columns="ticker")
df_wide.head()

# %% [markdown]
# ## 1.3 Getting data from Intrinio

# %% [markdown]
# ### How to do it...

# %% [markdown]
# 1. Import the libraries:

# %%
import intrinio_sdk as intrinio
import pandas as pd

# %% [markdown]
# 2. Authenticate using the personal API key and select the API:

# %%
intrinio.ApiClient().set_api_key("YOUR_KEY_HERE") 
security_api = intrinio.SecurityApi()

# %% [markdown]
# 3. Request the data:

# %%
r = security_api.get_security_stock_prices(
    identifier="AAPL", 
    start_date="2011-01-01",
    end_date="2021-12-31", 
    frequency="daily",
    page_size=10000
)

# %% [markdown]
# 4. Convert the results into a DataFrame:

# %%
df = (
    pd.DataFrame(r.stock_prices_dict)
    .sort_values("date")
    .set_index("date")
)

# %% [markdown]
# 5. Inspect the data:

# %%
print(f"Downloaded {df.shape[0]} rows of data.")

df.head()

# %% [markdown]
# ### There's more

# %% [markdown]
# 1. Get Coca-Cola's real-time stock price:

# %%
security_api.get_security_realtime_price("KO")

# %% [markdown]
# 2. Download news articles related to Coca-Cola:

# %%
r = intrinio.CompanyApi().get_company_news(
    identifier="KO", 
    page_size=100
)

df = pd.DataFrame(r.news_dict)
df.head()

# %% [markdown]
# 3. Search for companies connected to the search phrase:

# %% [markdown]
# Returns a list of companies recognized by the Thea API in the given `text` query string parameter.

# %%
r = intrinio.CompanyApi().recognize_company("Intel")
df = pd.DataFrame(r.companies_dict)
df

# %% [markdown]
# 4. Get Coca-Cola's intraday stock prices:

# %%
response = (
    security_api.get_security_intraday_prices(identifier="KO", 
                                              start_date="2021-01-02",
                                              end_date="2021-01-05",
                                              page_size=1000)
    )
df = pd.DataFrame(response.intraday_prices_dict)
df

# %% [markdown]
# 5. Get Coca-Cola's latest earnings record:

# %%
r = security_api.get_security_latest_earnings_record(identifier="KO")
print(r)

# %% [markdown]
# ## 1.4 Getting data from Alpha Vantage

# %% [markdown]
# ### How to do it...

# %% [markdown]
# 1. Import the libraries:

# %%
from alpha_vantage.cryptocurrencies import CryptoCurrencies

# %% [markdown]
# 2. Authenticate using the personal API key and select the API:

# %%
ALPHA_VANTAGE_API_KEY = "YOUR_KEY_HERE"

crypto_api = CryptoCurrencies(key=ALPHA_VANTAGE_API_KEY, 
                              output_format="pandas")

# %% [markdown]
# 3. Download the daily prices of Bitcoin, expressed in EUR:

# %%
data, meta_data = crypto_api.get_digital_currency_daily(
    symbol="BTC", 
    market="EUR"
)

# %%
meta_data

# %%
data

# %% [markdown]
# 4. Download the realtime exchange rate:

# %%
crypto_api.get_digital_currency_exchange_rate(
    from_currency="BTC", 
    to_currency="USD"
)[0].transpose()

# %% [markdown]
# ### There's more

# %% [markdown]
# 1. Import the libraries:

# %%
import requests
import pandas as pd
from io import BytesIO

# %% [markdown]
# 2. Download Bitcoin's intraday data:

# %%
AV_API_URL = "https://www.alphavantage.co/query"
parameters = {
    "function": "CRYPTO_INTRADAY",
    "symbol": "ETH",
    "market": "USD",
    "interval": "30min",
    "outputsize": "full",
    "apikey": ALPHA_VANTAGE_API_KEY
}
r = requests.get(AV_API_URL, params=parameters)
data = r.json()
df = (
    pd.DataFrame(data["Time Series Crypto (30min)"])
    .transpose()
)
df

# %% [markdown]
# 3. Download the upcoming earnings announcements:

# %%
AV_API_URL = "https://www.alphavantage.co/query" 
parameters = {
    "function": "EARNINGS_CALENDAR",
    "horizon": "3month",
    "apikey": ALPHA_VANTAGE_API_KEY
}

r = requests.get(AV_API_URL, params=parameters)
pd.read_csv(BytesIO(r.content))

# %%
type(r.content)

# %% [markdown]
# ### Bonus
#
# This section includes some additional short recipes not published in the book.

# %% [markdown]
# 1. Get Tesla's earnings:

# %%
AV_API_URL = "https://www.alphavantage.co/query" 
parameters = {
    "function": "EARNINGS",
    "symbol": "TSLA", 
    "apikey": ALPHA_VANTAGE_API_KEY
}
r = requests.get(AV_API_URL,  params=parameters)
data = r.json()

# %%
data.keys()

# %%
df = pd.DataFrame(data["quarterlyEarnings"])
df.head()

# %% [markdown]
# 2. Download the upcoming IPOs:

# %%
import csv

AV_API_URL = "https://www.alphavantage.co/query" 
parameters = {
    "function": "IPO_CALENDAR",
    "apikey": ALPHA_VANTAGE_API_KEY
}

with requests.Session() as s:
    download = s.get(AV_API_URL, params=parameters)
    decoded_content = download.content.decode("utf-8")
    ipos_list = list(csv.reader(decoded_content.splitlines(), delimiter=","))

df = pd.DataFrame(ipos_list[1:], columns=ipos_list[0])
df

# %% [markdown]
# 3. Download Google's stock prices using the `TimeSeries` module:

# %%
from alpha_vantage.timeseries import TimeSeries

ts = TimeSeries(key=ALPHA_VANTAGE_API_KEY, output_format="pandas")
data, _ = ts.get_daily("GOOGL", outputsize="full")
print(f"Downloaded {len(data)} observations")
data

# %% [markdown]
# 4. Similarly, we can download the intraday prices:

# %%
data, _ = ts.get_intraday("GOOGL", interval="5min", outputsize="full")
data

# %% [markdown]
# ## 1.5 Getting data from CoinGecko

# %% [markdown]
# ### How to do it...

# %% [markdown]
# 1. Import the libraries:

# %%
from pycoingecko import CoinGeckoAPI
from datetime import datetime
import pandas as pd

# %% [markdown]
# 2. Instantiate the CoinGecko API:

# %%
cg = CoinGeckoAPI()

# %% [markdown]
# 3. Get Bitcoin's OHLC prices from the last 14 days:

# %%
ohlc = cg.get_coin_ohlc_by_id(
    id="bitcoin", vs_currency="usd", days="14"
)
ohlc_df = pd.DataFrame(ohlc)
ohlc_df.columns = ["date", "open", "high", "low", "close"]
ohlc_df["date"] = pd.to_datetime(ohlc_df["date"], unit="ms")
ohlc_df
# Out:
#                   date     open     high      low    close
# 0  2024-10-25 12:00:00  67475.0  68097.0  67350.0  68081.0
# 1  2024-10-25 16:00:00  68089.0  68655.0  67378.0  67378.0
# 2  2024-10-25 20:00:00  67683.0  67834.0  65896.0  66920.0
# 3  2024-10-26 00:00:00  66742.0  67260.0  65564.0  66586.0
# 4  2024-10-26 04:00:00  66649.0  66872.0  66408.0  66842.0
# ..                 ...      ...      ...      ...      ...
# 79 2024-11-07 16:00:00  74776.0  76048.0  74669.0  76048.0
# 80 2024-11-07 20:00:00  76119.0  76677.0  75623.0  76486.0
# 81 2024-11-08 00:00:00  76619.0  76873.0  75667.0  75987.0
# 82 2024-11-08 04:00:00  75895.0  76376.0  75684.0  75934.0
# 83 2024-11-08 08:00:00  75992.0  76313.0  75793.0  76313.0
#
# [84 rows x 5 columns]

# %% [markdown]
# ### There's more

# %% [markdown]
# 1. Get the top 7 trending coins (based on the # of searches in the last 24h) from CoinGecko:

# %%
trending_coins = cg.get_search_trending()
(
    pd.DataFrame([coin["item"] for coin in trending_coins["coins"]])
    .drop(columns=["thumb", "small", "large"])
)
# Out:
#                          id  coin_id              name  symbol  \
# 0                   notcoin    33453           Notcoin     NOT
# 1                     grass    40094             Grass   GRASS
# 2             swell-network    28777             Swell   SWELL
# 3                   cardano      975           Cardano     ADA
# 4            drift-protocol    37509    Drift Protocol   DRIFT
# 5                    solana     4128            Solana     SOL
# 6   jupiter-exchange-solana    34188           Jupiter     JUP
# 7                       sui    26375               Sui     SUI
# 8            solidus-aitech    22114   Solidus Ai Tech  AITECH
# 9                  dogecoin        5          Dogecoin    DOGE
# 10           cetus-protocol    30256    Cetus Protocol   CETUS
# 11         goatseus-maximus    50717  Goatseus Maximus    GOAT
# 12                     pepe    29850              Pepe    PEPE
# 13                 ethereum      279          Ethereum     ETH
# 14                   kamino    35801            Kamino    KMNO
#
#     market_cap_rank              slug     price_btc  score  \
# 0               133           notcoin  8.334023e-08      0
# 1               107             grass  4.395260e-05      1
# 2               643     swell-network  5.960033e-07      2
# 3                10           cardano  5.634545e-06      3
# 4               286    drift-protocol  1.148418e-05      4
# 5                 4            solana  2.660674e-03      5
# 6                66           jupiter  1.475901e-05      6
# 7                20               sui  3.040751e-05      7
# 8               449   solidus-ai-tech  1.260470e-06      8
# 9                 8          dogecoin  2.603858e-06      9
# 10              273    cetus-protocol  5.355081e-06     10
# 11              104  goatseus-maximus  1.096798e-05     11
# 12               29              pepe  1.416426e-10     12
# 13                2          ethereum  3.831153e-02     13
# 14              333            kamino  1.651762e-06     14
#
#                                                  data
# 0   {'price': 0.006341017345376283, 'price_btc': '...
# 1   {'price': 3.344173594928206, 'price_btc': '0.0...
# 2   {'price': 0.045347456915046006, 'price_btc': '...
# 3   {'price': 0.42870951914272587, 'price_btc': '0...
# 4   {'price': 0.8737843527948843, 'price_btc': '0....
# 5   {'price': 202.43980689108028, 'price_btc': '0....
# 6   {'price': 1.122952975923044, 'price_btc': '0.0...
# 7   {'price': 2.3135833534452344, 'price_btc': '0....
# 8   {'price': 0.09590402357258465, 'price_btc': '0...
# 9   {'price': 0.19811687446977577, 'price_btc': '0...
# 10  {'price': 0.4074461843768485, 'price_btc': '0....
# 11  {'price': 0.8345084618550894, 'price_btc': '0....
# 12  {'price': 1.0777005422558522e-05, 'price_btc':...
# 13  {'price': 2914.9679102976133, 'price_btc': '0....
# 14  {'price': 0.1256757818722311, 'price_btc': '0....

# %% [markdown]
# 2. Get Bitcoin's current price in USD:

# %%
cg.get_price(ids="bitcoin", vs_currencies="usd")

# %% [markdown]
# ### Bonus
#
# This section includes some additional short recipes not published in the book.

# %% [markdown]
# 1. Get current price of ETH and BTC in USD and EUR:

# %%
cg.get_price(ids=["bitcoin", "ethereum"], vs_currencies=["usd", "eur"])

# %% [markdown]
# 2. Get the current BTC/USD eschange rate, market capitalization, 24h volumne and change and the last-updated timestamp:

# %%
cg.get_price(ids="bitcoin", vs_currencies="usd", 
             include_market_cap=True, 
             include_24hr_vol=True, 
             include_24hr_change=True, 
             include_last_updated_at=True)

# %% [markdown]
# 3. Get the list of all supported coin ids, together with their name and symbol:

# %%
pd.DataFrame(cg.get_coins_list())

# %% [markdown]
# 4. Get all the coins market data:

# %%
pd.DataFrame(cg.get_coins_markets(vs_currency="eur"))

# %% [markdown]
# 5. Get all the supported crypto exchanges:

# %%
exchanges_df = pd.DataFrame(cg.get_exchanges_list(per_page=250))
exchanges_df.head()

# %% [markdown]
# 6. Get a summary of DEFI:

# %%
cg.get_global_decentralized_finance_defi()
